# %%
from qutip import *

# %%
from tiqs import *

# %%
traslation("str")
# Out:
# 'trs'

# %%
dir(tiqs)
# Out:
# ['Bloch',
#  'Bloch3d',
#  'Cubic_Spline',
#  'Distribution',
#  'Gate',
#  'HarmonicOscillatorProbabilityFunction',
#  'HarmonicOscillatorWaveFunction',
#  'MidpointNorm',
#  'Odedata',
#  'Odeoptions',
#  'Options',
#  'QDistribution',
#  'Qobj',
#  'QubitCircuit',
#  'TwoModeQuadratureCorrelation',
#  'WignerDistribution',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'about',
#  'absolute_import',
#  'average_gate_fidelity',
#  'basis',
#  'bell_state',
#  'berkeley',
#  'bloch',
#  'bloch3d',
#  'bloch_redfield',
#  'bloch_redfield_solve',
#  'bloch_redfield_tensor',
#  'bra',
#  'breadth_first_search',
#  'brmesolve',
#  'build_appropriate_jumps',
#  'build_preconditioner',
#  'bures_angle',
#  'bures_dist',
#  'cfg_vars',
#  'charge',
#  'chi_to_choi',
#  'choi_to_chi',
#  'choi_to_kraus',
#  'choi_to_super',
#  'circuit',
#  'circuit_latex',
#  'cite',
#  'clebsch',
#  'cnot',
# ...

# %%
write_state_as_number(17,36,5)
# Out:
# '0000H'

# %%
'0000[10][2][3]'
